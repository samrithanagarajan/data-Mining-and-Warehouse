# %%
! pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5979 sha256=f241c31c49af2ed2d7fb197136fe3f8f1ecd1b6761086f76ed8ed1174b315a36
#   Stored in directory: c:\users\samritha\appdata\local\pip\cache\wheels\1b\02\6c\a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori

# %%
data = pd.read_csv('FertilizersProduct.csv',encoding='latin-1')
data
# Out:
#         Area Code         Area  Item Code  \
# 0               2  Afghanistan       4007
# 1               2  Afghanistan       4007
# 2               2  Afghanistan       4007
# 3               2  Afghanistan       4007
# 4               2  Afghanistan       4007
# ...           ...          ...        ...
# 164463        181     Zimbabwe       4006
# 164464        181     Zimbabwe       4006
# 164465        181     Zimbabwe       4006
# 164466        181     Zimbabwe       4006
# 164467        181     Zimbabwe       4006
#
#                                              Item  Element Code  \
# 0                              Ammonia, anhydrous          5610
# 1                              Ammonia, anhydrous          5610
# 2                              Ammonia, anhydrous          5610
# 3                              Ammonia, anhydrous          5622
# 4                              Ammonia, anhydrous          5622
# ...                                           ...           ...
# ...

# %%
data.shape
# Out:
# (164468, 11)

# %%
records = []
for i in range(0,10):
    records.append([str(data.values[i,j]) for j in range(0,10)])

# %%
for sets in records:
    print(sets)
# Out:
# ['2', 'Afghanistan', '4007', 'Ammonia, anhydrous', '5610', 'Import Quantity', '2011', '2011', 'tonnes', '4.49']
# ['2', 'Afghanistan', '4007', 'Ammonia, anhydrous', '5610', 'Import Quantity', '2014', '2014', 'tonnes', '2.0']
# ['2', 'Afghanistan', '4007', 'Ammonia, anhydrous', '5610', 'Import Quantity', '2017', '2017', 'tonnes', '2.07']
# ['2', 'Afghanistan', '4007', 'Ammonia, anhydrous', '5622', 'Import Value', '2011', '2011', '1000 US$', '2.69']
# ['2', 'Afghanistan', '4007', 'Ammonia, anhydrous', '5622', 'Import Value', '2014', '2014', '1000 US$', '1.07']
# ['2', 'Afghanistan', '4007', 'Ammonia, anhydrous', '5622', 'Import Value', '2017', '2017', '1000 US$', '1.24']
# ['2', 'Afghanistan', '4003', 'Ammonium nitrate (AN)', '5610', 'Import Quantity', '2002', '2002', 'tonnes', '1786.13']
# ['2', 'Afghanistan', '4003', 'Ammonium nitrate (AN)', '5610', 'Import Quantity', '2007', '2007', 'tonnes', '0.64']
# ...

# %%
association_rules=apriori(records,min_support=0.5,min_confidence=0.7,min_length=2)

# %%
association_results=list(association_rules)

# %%
print(len(association_results))
# Out:
# 41

# %%
association_results[0]
# Out:
# RelationRecord(items=frozenset({'2'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'2'}), confidence=1.0, lift=1.0)])

# %%
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    print("Rule :"+ str(item[0]) + "->" + str(item[1]))
    print("Support : {}".format(item[1]))
    print("Confidence : {}".format(item[2][0][2]))
    print("Lift : {}".format(item[2][0][3]))
    print("\n------------------------------------------------\n")
# Out:
# Rule :frozenset({'2'})->1.0
# Support : 1.0
# Confidence : 1.0
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'5610'})->0.7
# Support : 0.7
# Confidence : 0.7
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'Afghanistan'})->1.0
# Support : 1.0
# Confidence : 1.0
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'Import Quantity'})->0.7
# Support : 0.7
# Confidence : 0.7
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'tonnes'})->0.7
# Support : 0.7
# Confidence : 0.7
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'4007', '2'})->0.6
# Support : 0.6
# Confidence : 1.0
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'2', '5610'})->0.7
# Support : 0.7
# Confidence : 0.7
# Lift : 1.0
#
# ------------------------------------------------
#
# ...

# %%
association_rules1=apriori(records,min_support=0.004)

# %%
association_results1=list(association_rules1)

# %%
print(len(association_results1))
# Out:
# 4127

# %%
for item in association_results1:
    pair = item[0]
    items = [x for x in pair]
    print("Rule :"+ str(item[0]) + "->" + str(item[1]))
    print("Support : {}".format(item[1]))
    print("Confidence : {}".format(item[2][0][2]))
    print("Lift : {}".format(item[2][0][3]))
    print("\n------------------------------------------------\n")
# Out:
# Rule :frozenset({'0.64'})->0.1
# Support : 0.1
# Confidence : 0.1
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'1.0'})->0.1
# Support : 0.1
# Confidence : 0.1
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'1.07'})->0.1
# Support : 0.1
# Confidence : 0.1
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'1.24'})->0.1
# Support : 0.1
# Confidence : 0.1
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'1000 US$'})->0.3
# Support : 0.3
# Confidence : 0.3
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'1456.8'})->0.1
# Support : 0.1
# Confidence : 0.1
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'1786.13'})->0.1
# Support : 0.1
# Confidence : 0.1
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'2'})->1.0
# ...
